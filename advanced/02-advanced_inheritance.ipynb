# %% [markdown]
# # Advanced inheritance
#
# **Outline**:
# - Single inheritance resolution
#     * ABC
#     * super()
# - Diamond shape inheritance and MRO
#     * C3 algo
#     * inspect
# - Pitfalls
# - Mixin
# - Metaclass
# - Composition over inheritance
# - Typing
# - Dynamic object creation? --> decoration of class (like dataclass?)
