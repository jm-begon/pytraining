# %% [markdown]
# # Resolution in Python
#
# Brainstorming:
# - Descriptor
#     * Rollback example
#     * Proxy pattern (lazy)
# - MRO: just mention, topic of another lecture
# - `getattr`, `setattr`
# - Monkey Patching and mocking
